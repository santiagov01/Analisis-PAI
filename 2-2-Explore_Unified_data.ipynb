# %%
import pandas as pd

# Archivo de entrada
archivo = R"D:\Estudio\OneDrive - Universidad de Antioquia\Estudio\PAI\Codigo\BaseDatos\BD Quindio unificados V2\Quindio_Movil_Manual_unificado.csv"

# Cargar el archivo (primera hoja por defecto)
df = pd.read_csv(archivo)

#seleccionar algunas variables
df = df[["Peso frutos cosechados (Kg)", "Numero frutos cosechados "]]

df.describe().T
# Out:
#                               count      mean       std  min    25%    50%  \
# Peso frutos cosechados (Kg)  1975.0  0.429088  0.370102  0.0  0.143  0.366
# Numero frutos cosechados     1975.0  2.899241  2.471617  0.0  1.000  3.000
#
#                                75%     max
# Peso frutos cosechados (Kg)  0.633   2.486
# Numero frutos cosechados     4.000  22.000
